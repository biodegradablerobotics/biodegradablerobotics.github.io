# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Mar  3 13:54:15 2021

@author: danaukes
"""

import pandas as pd
import numpy
import matplotlib.pyplot as plt
import scipy.interpolate as si

df=pd.read_csv(r'E:\OneDrive - Arizona State University\Spring 2021\EGR 557 Foldable Robotics\biodegradablerobotics.github.io\Code\TrackerData\MidJointPend.txt', sep=',')

#x = df.x.astype('float64').to_numpy()
x = df.x.to_numpy()
y = df.y.to_numpy()
t = df.t.to_numpy()


xy = numpy.array([x,y]).T
f = si.interp1d(t,xy.T,fill_value='extrapolate',kind='quadratic')
new_t = numpy.r_[0:t[-1]:.1]

plt.figure()
plt.plot(t,x)
plt.plot(new_t,f(new_t)[0])

plt.figure()
plt.plot(t,y)
plt.plot(new_t,f(new_t)[1])
plt.figure()
plt.plot(x,y)

# %%
df=pd.read_csv(r'E:\OneDrive - Arizona State University\Spring 2021\EGR 557 Foldable Robotics\biodegradablerobotics.github.io\Code\TrackerData\EndJointPend.txt', sep=',')

#x = df.x.astype('float64').to_numpy()
x2 = df.x.to_numpy()
y2 = df.y.to_numpy()
t2 = df.t.to_numpy()


xy2 = numpy.array([x2,y2]).T
f2 = si.interp1d(t2,xy2.T,fill_value='extrapolate',kind='quadratic')
new_t2 = numpy.r_[0:t2[-1]:.1]

plt.figure()
plt.plot(t2,x2)
plt.plot(new_t2,f2(new_t2)[0])

plt.figure()
plt.plot(t2,y2)
plt.plot(new_t2,f2(new_t2)[1])
plt.figure()
plt.plot(x2,y2)

# %%
df=pd.read_csv(r'E:\OneDrive - Arizona State University\Spring 2021\EGR 557 Foldable Robotics\TrackerVideos\TopJoint_2.txt', sep=',')

#x = df.x.astype('float64').to_numpy()
x3 = df.x.to_numpy()
y3 = df.y.to_numpy()
t3 = df.t.to_numpy()


xy3 = numpy.array([x3,y3]).T
f3 = si.interp1d(t3,xy3.T,fill_value='extrapolate',kind='quadratic')
new_t3 = numpy.r_[0:t3[-1]:.1]

plt.figure()
plt.plot(t3,x3)
plt.plot(new_t3,f3(new_t3)[0])

plt.figure()
plt.plot(t3,y3)
plt.plot(new_t3,f3(new_t3)[1])
plt.figure()
plt.plot(x3,y3)

# %%
plt.figure()
plt.plot(x,y)
plt.plot(x2,y2)
